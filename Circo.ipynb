# %% [markdown]
# <a href="https://colab.research.google.com/github/AgustinaAscui/proyecto-evoluci-n-del-circo/blob/main/Circo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Carga de la base de datos limpia
df_circo = pd.read_csv('base_datos_circo_limpia.csv')

# Visualización de las primeras líneas
print(df_circo.head())

# Verificación de tipos de datos y nulos
print(df_circo.info())
# Out:
#           Pais_Caso Tipo_Entidad  Año_Hito Uso_Animales  \
# 0           Austria         País    2005.0           No
# 1           Bolivia         País    2009.0           No
# 2             Chile         País    2007.0           Sí
# 3  Cirque du Soleil     Compañía    1984.0           No
# 4     Ringling Bros     Compañía    2017.0           No
#
#                     Tipo_Restriccion Formacion_Predominante Estatus_Actual
# 0      Prohibición nacional salvajes                    NaN        Vigente
# 1  Prohibición salvajes y domésticos                    NaN        Vigente
# 2            Regulación (Ley 20.216)                  Mixta        Vigente
# 3                                NaN     Académica/Talleres         Activo
# 4             Eliminación voluntaria      Tradicional/Mixta         Activo
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ...
